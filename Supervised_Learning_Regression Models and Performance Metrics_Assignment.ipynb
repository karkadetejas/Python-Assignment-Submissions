# %% [markdown]
# # Supervised Learning - Regression Models and Performance Metrics Assignment

# %% [markdown]
# ## Q1. What is Simple Linear Regression (SLR)? Explain its purpose.
#
# Simple Linear Regression is a supervised machine learning algorithm that finds the relationship between one independent variable (X) and one dependent variable (Y). It fits a straight line to the data to predict the value of the dependent variable. Its main purpose is to understand how one variable affects another and make future predictions.

# %% [markdown]
# ## Q2. What are the key assumptions of Simple Linear Regression?
#
# The main assumptions of Simple Linear Regression are:
#
# - There should be a linear relationship between X and Y.
# - The observations should be independent.
# - The error terms should have constant variance (Homoscedasticity).
# - The residuals should be normally distributed.
# - There should be no significant outliers affecting the model.

# %% [markdown]
# ## Q3. Write the mathematical equation for a simple linear regression model and explain each term.
#
# The equation of Simple Linear Regression is:
#
# **Y = β₀ + β₁X**
#
# Where:
#
# - **Y** = Dependent variable (Predicted value)
# - **X** = Independent variable
# - **β₀** = Intercept (Value of Y when X = 0)
# - **β₁** = Slope (Change in Y for every one-unit increase in X)

# %% [markdown]
# ## Q4. Provide a real-world example where Simple Linear Regression can be applied.
#
# A company can use Simple Linear Regression to predict house prices based on the size of the house. Here, the house area is the independent variable, and the house price is the dependent variable. As the size increases, the price generally increases.

# %% [markdown]
# ## Q5. What is the method of least squares in linear regression?
#
# The Least Squares Method is used to find the best-fit regression line by minimizing the sum of squared differences between the actual values and the predicted values. It helps in finding the most accurate slope and intercept for the regression line.

# %% [markdown]
# ## Q6. What is Logistic Regression? How does it differ from Linear Regression?
#
# Logistic Regression is a supervised learning algorithm used for classification problems, whereas Linear Regression is used for predicting continuous values.
#
# Linear Regression predicts numerical values such as salary or house price, while Logistic Regression predicts categories such as Yes/No or Pass/Fail using probabilities.

# %% [markdown]
# ## Q7. Name and briefly describe three common evaluation metrics for regression models.
#
# ### 1. Mean Absolute Error (MAE)
# It calculates the average absolute difference between actual and predicted values. Lower MAE indicates better performance.
#
# ### 2. Mean Squared Error (MSE)
# It calculates the average squared difference between actual and predicted values. Larger errors receive higher penalties.
#
# ### 3. Root Mean Squared Error (RMSE)
# It is the square root of MSE and is easier to interpret because it is in the same unit as the target variable.

# %% [markdown]
# ## Q8. What is the purpose of the R-squared metric in regression analysis?
#
# R-squared measures how well the regression model explains the variation in the dependent variable. Its value ranges from 0 to 1. A higher R-squared value indicates that the model fits the data better.

# %% [markdown]
# ## Q9. Practical Question

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
Y = np.array([2, 4, 6, 8, 10])

# Create model
model = LinearRegression()

# Train model
model.fit(X, Y)

# Print slope and intercept
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope: 2.0
# Intercept: 0.0

# %% [markdown]
# ## Q10. How do you interpret the coefficients in a simple linear regression model?
#
# The coefficient (slope) shows how much the dependent variable changes when the independent variable increases by one unit. A positive coefficient means the dependent variable increases, while a negative coefficient means it decreases. The intercept represents the predicted value of the dependent variable when the independent variable is zero.
